# %%
from requests_html import HTMLSession

session = HTMLSession()

r = session.get("https://www.liepin.com/zhaopin/?key=数据分析")

# 通过xpath找 “数据分析”岗位的招聘及招聘网址
news = r.html.xpath('//div[@class="job-info"]/h3/a')

for new in news:
    print(new.text)  # 获得工作标题
    print(new.absolute_links)  # 获得工作链接
# Out:
# 数据分析师
# {'https://www.liepin.com/job/1925957529.shtml'}
# 数据分析师
# {'https://www.liepin.com/job/1926634215.shtml'}
# 数据分析师
# {'https://www.liepin.com/job/1926676203.shtml'}
# 资深数据分析
# {'https://www.liepin.com/job/1926564367.shtml'}
# 数据分析专员
# {'https://www.liepin.com/job/1926535789.shtml'}
# 数据管理与医学统计经理（上市公司）
# {'https://www.liepin.com/job/1926484611.shtml'}
# 数据分析担当
# {'https://www.liepin.com/job/1924765821.shtml'}
# 光谱诊断数据分析工程师
# {'https://www.liepin.com/job/1926735083.shtml'}
# 充电宝-业务数据分析
# {'https://www.liepin.com/job/1926734857.shtml'}
# 数据分析师（海外产品） (MJ000164)
# {'https://www.liepin.com/job/1926734217.shtml'}
# CRM数据分析师（电商）
# {'https://www.liepin.com/job/1926733987.shtml'}
# 金融工程师（数据分析岗位）
# {'https://www.liepin.com/job/1926732845.shtml'}
# 数据分析师
# {'https://www.liepin.com/job/1926731459.shtml'}
# 数据分析师
# {'https://www.liepin.com/job/1926730977.shtml'}
# Oracle EBS数据分析
# {'https://www.liepin.com/job/1926730733.shtml'}
# Oracle EBS数据分析
# {'https://www.liepin.com/job/1926730701.shtml'}
# 高级数据分析
# {'https://www.liepin.com/job/1926730577.shtml'}
# 财务专员/出纳/数据分析
# {'https://www.liepin.com/job/1926729709.shtml'}
# 客服主管（数据分析、巡检、运维支持方向）-集团本部-天津(J52624)
# {'https://www.liepin.com/job/1926729197.shtml'}
# 上海-临床数据分析（合同DM）
# {'https://www.liepin.com/job/1926728577.shtml'}
# 阿里/京东数据分析专员
# {'https://www.liepin.com/job/1926728385.shtml'}
# 数据分析师（应届）
# {'https://www.liepin.com/job/1926727683.shtml'}
# 数据分析师
# {'https://www.liepin.com/job/1926726723.shtml'}
# 数据分析师
# {'https://www.liepin.com/job/1926725909.shtml'}
# 销售运营经理（数据分析） (MJ000521)
# {'https://www.liepin.com/job/1926725287.shtml'}
# 数据分析师
# {'https://www.liepin.com/job/1926725283.shtml'}
# 数据分析员（第三方）
# {'https://www.liepin.com/job/1926724529.shtml'}
# 人资数据分析负责人
# {'https://www.liepin.com/job/1926724385.shtml'}
# 高级数据分析师
# {'https://www.liepin.com/job/1926724241.shtml'}
# 数据分析专员
# {'https://www.liepin.com/job/1926724063.shtml'}
# 商业数据分析师
# {'https://www.liepin.com/job/1926723939.shtml'}
# 高级数据分析师
# {'https://www.liepin.com/job/1926723617.shtml'}
# 数据分析师（偏业务）
# {'https://www.liepin.com/job/1926723393.shtml'}
# 高级运营-数据分析方向
# {'https://www.liepin.com/job/1926722357.shtml'}
# 高级研发工程师（数据分析方向）
# {'https://www.liepin.com/job/1926721473.shtml'}
# 数据分析师
# {'https://www.liepin.com/job/1926718961.shtml'}
# 高级数据分析师
# {'https://www.liepin.com/job/1926715921.shtml'}
# 高级数据分析师
# {'https://www.liepin.com/job/1926715159.shtml'}
# 环境监测与数据分析工程师
# {'https://www.liepin.com/job/1926714939.shtml'}
# 数据分析师（互联网行业）
# {'https://www.liepin.com/job/1926714609.shtml'}

# %%
from requests_html import HTMLSession

session = HTMLSession()

r = session.get("https://www.liepin.com/zhaopin/?init=-1&searchField=1&headckid=029660d1a8a56266&flushckid=1&fromSearchBtn=2&salary=15$20&ckid=753f724f51a06bad&subIndustry=&industryType=industry_01&industries=040&key=%E9%94%80%E5%94%AE&siTag=fw3F47vuJXKzz2u6l56qUQ%7E1p1Hf6Iytm4nd3ac31P45g&d_sfrom=search_fp_nvbar&d_ckId=58b427c8b7b8a46b222935c8c5f7959c&d_curPage=0&d_pageSize=40&d_headId=a931a34ae0c2bbe18ee2160af444155c")

# 通过xpath找 全国内与互联网/电商相关的年薪15-20w的“销售”岗位
news = r.html.xpath('//div[@class="job-info"]')

for new in news:
    print(new.text)  # 获得有关“销售”岗位相关信息
    print(new.absolute_links)  # 获得有关“销售”岗位链接
# Out:
# 课程销售顾问
# 15-30k·12薪 广州-天河区 大专及以上 经验不限
# 1小时前 投递后：72小时反馈
# {'https://www.liepin.com/job/1915111943.shtml', 'https://www.liepin.com/gz/zhaopin/'}
# 销售经理
# 6-18k·12薪 北京-朝阳区 统招本科 1年以上
# 2020-02-26 投递后：10个工作日内反馈
# {'https://www.liepin.com/job/1926160335.shtml'}
# 礼品渠道销售经理
# 8-15k·12薪 杭州 学历不限 1年以上
# 19小时前 投递后：72小时反馈
# {'https://www.liepin.com/hz/zhaopin/', 'https://www.liepin.com/job/1926588867.shtml'}
# 课程销售
# 8-24k·12薪 北京-苏州街 大专及以上 经验不限
# 2020-03-12 投递后：48小时反馈
# {'https://www.liepin.com/job/1913423206.shtml', 'https://www.liepin.com/bj/zhaopin/'}
# 销售专员 市场专员（保健品/化妆品/电子烟）
# 8-13k·12薪 深圳 大专及以上 经验不限
# 2小时前 投递后：72小时反馈
# {'https://www.liepin.com/job/1926458801.shtml', 'https://www.liepin.com/sz/zhaopin/'}
# 大客户销售经理
# 10-20k·12薪 深圳 学历不限 2年以上
# 20小时前 投递后：72小时反馈
# {'https://www.liepin.com/job/1926462039.shtml', 'https://www.liepin.com/sz/zhaopin/'}
# 渠道销售（职业教育项目组）
# 面议 北京-中关村 大专及以上 1年以上
# 2020-03-12 投递后：7个工作日内反馈
# {'https://www.liepin.com/job/1926437143.shtml', 'https://www.liepin.com/bj/zhaopin/'}
# 物流大客户销售、项目营销、市场营销、大三方营销，项目拓展
# 面议 上海-徐泾 大专及以上 5年以上
# 5分钟前 投递后：72小时反馈
# {'https://www.liepin.com/sh/zhaopin/', 'https://www.liepin.com/job/1926759681.shtml'}
# 6小时前 投递后：5个工作日内反馈
# {'https://www.liepin.com/sh/zhaopin/', 'https://www.liepin.com/job/1926749949.shtml'}
# 销售经理
# 8-13k·12薪 温州 学历不限 经验不限
# 6小时前 投递后：5个工作日内反馈
# {'https://www.liepin.com/job/1926749345.shtml', 'https://www.liepin.com/wenzhou/zhaopin/'}
# 销售经理（北京）
# 10-15k·12薪 北京 大专及以上 5年以上
# 6小时前 投递后：5个工作日内反馈
# {'https://www.liepin.com/job/1926748455.shtml', 'https://www.liepin.com/bj/zhaopin/'}
# 销售经理（深圳）
# 10-15k·12薪 深圳 大专及以上 5年以上
# 6小时前 投递后：5个工作日内反馈
# {'https://www.liepin.com/job/1926748445.shtml', 'https://www.liepin.com/sz/zhaopin/'}

# %%
# 引入resquests-html模块
from requests_html import HTMLSession

session = HTMLSession()

# 获取（'某网站'）的数据
r = session.get("https://www.liepin.com/zhaopin/?key=投资经理")

# 通过xpath找 有关“投资经理”岗位的其他信息（薪资、公司地址、要求、年限等）
news = r.html.xpath('//div[@class="job-info"]/h3|//div[@class="job-info"]/p[1]')

# 导出数据（循环）
for new in news:
    print(new.text)  # 获得“投资经理”岗位的其他信息（薪资、地址等）
# Out:
# 商品期货投资经理
# 面议 上海 统招本科 3年以上
# 商业总部-投资测算主管/经理（住宅请勿投递谢）
# 19-27k·12薪 北京-四惠 统招本科 3年以上
# 投资拓展经理/主管
# 20-30k·12薪 合肥-潜山路 本科及以上 3年以上
# 投资拓展经理
# 面议 北京-丰台体育馆 统招本科 5年以上
# 投资经理（新疆）
# 12-18k·12薪 乌鲁木齐-新市区 本科及以上 3年以上
# 投资拓展经理/主任
# 9-15k·16薪 东莞-东城区 统招本科 经验不限
# 投资顾问/理财经理
# 面议 上海-陆家嘴 大专及以上 2年以上
# 海外商务经理(投资方向)(海外事业部)
# 面议 上海-静安区 硕士及以上 2年以上
# 投资拓展经理
# 15-20k·12薪 广州-珠江新城 本科及以上 5年以上
# 投资人关系经理
# 10-15k·12薪 深圳-南山区 本科及以上 3年以上
# 投资发展中心区域总经理
# 面议 嘉兴-南湖区 大专及以上 5年以上
# 投资经理/总监
# 15-30k·12薪 上海 统招本科 5年以上
# 投资拓展经理
# 面议 青岛 统招本科 5年以上
# 恒天财富-理财经理/投资顾问
# 30-60k·12薪 北京 统招本科 3年以上
# 投资经理
# 8-12k·12薪 宜昌 本科及以上 2年以上
# 投资经理助理岗
# 面议 上海-浦东新区 硕士及以上 2年以上
# 投资理财经理
# 8-16k·12薪 东莞-莞城区 大专及以上 3年以上
# 投资经理岗
# 面议 上海-浦东新区 硕士及以上 5年以上
# 投资经理（信息技术方向）
# 15-20k·12薪 深圳-福田区 本科及以上 3年以上
# 投资拓展经理-重庆区域公司
# 面议 重庆 本科及以上 3年以上
# 投资经理-大健康方向(J11499)
# 20-30k·12薪 上海-七宝 统招本科 2年以上
# 投资经理（信息技术、工业机器人领域）南京
# 面议 南京 统招本科 5年以上
# 投资拓展经理（重庆）
# 20-30k·12薪 成都 统招本科 5年以上
# 投资拓展经理（成都、重庆）
# 20-30k·12薪 成都 统招本科 5年以上
# 副总经理（投资拓展）
# 25-45k·12薪 上海 大专及以上 8年以上
# 投资经理
# 10-20k·12薪 福州-鼓东 大专及以上 3年以上
# 投资经理
# 面议 北京 本科及以上 7年以上
# 投资经理
# 15-25k·12薪 广州-黄埔区 本科及以上 5年以上
# 地产投资总经理
# 40-70k·12薪 北京 统招本科 5年以上
# 投资部主管/经理
# 7-10k·12薪 深圳-宝安区 本科及以上 3年以上
# 部门副经理（河北建投水务投资有限公司）
# 面议 石家庄 统招本科 5年以上
# 投资专业经理
# 面议 郑州-郑东新区 统招本科 3年以上
# 投资拓展经理/主管
# 15-25k·12薪 成都 统招本科 3年以上
# 地产投资经理
# 15-25k·12薪 上海-浦东新区 统招本科 3年以上
# 地产投资经理（法务方向）
# 15-20k·12薪 上海-浦东新区 统招本科 3年以上
# 法务经理（投资方向）
# 15-20k·12薪 上海-浦东新区 统招本科 3年以上
# 投资高级经理
# 30-40k·12薪 苏州-松陵 本科及以上 5年以上
# 投资经理
# 15-25k·12薪 上海 本科及以上 2年以上
# 高级投资经理
# 面议 深圳 本科及以上 3年以上
# 投资经理
# 10-15k·12薪 西安 硕士及以上 3年以上

# %%
from requests_html import HTMLSession

session = HTMLSession()

r = session.get("http://www.gov.cn/xinwen/tupian/index.htm")

# 通过xpath找 新闻图片图说、图片地址
news = r.html.xpath('//div[@class="subtitle"]/a')
items = r.html.xpath('//div[@class="pannel-image"]/a/img/@src')

# 获取新闻图片信息（循环）
for new in news:
    print("图片信息:",new.text)

# 获取新闻图片地址（循环）
for item in items:
    print("图片地址:",item)
# Out:
# 图片信息: 李克强会见巴基斯坦总统阿尔维
# 图片信息: 国务院联防联控机制就药物疫苗和检测试剂研发攻关最新情况举行发布会
# 图片信息: 国新办举行援助湖北医疗队专家介绍新冠肺炎重症科学救治记者见面会
# 图片信息: 春日大棚劳作忙
# 图片信息: 陕西汉阴：遍地金黄满眼春
# 图片信息: 山东滨州：开足马力 赶制订单
# 图片信息: 依依惜别 窗里窗外
# 图片信息: 广东进一步优化境外疫情输入防控措施
# 图片信息: 西安：农技下乡助春耕
# 图片信息: 河北滦州：“空中课堂”学非遗
# 图片信息: 上海科技馆和自然博物馆恢复开放
# 图片信息: 创作“江南茧画” 迎鼠年新春
# 图片信息: 春日里的“鹭鸟王国”
# 图片信息: 南京：谷里花开迎春来
# 图片信息: 吉林莫莫格湿地迎来首批北迁东方白鹳
# 图片地址: /govweb/c1426/202003/5492522/images/9bd7e7e0b2e741319c3d55a3806de6d2.jpg
# 图片地址: /govweb/c1465t/202003/5492504/images/bbbd31e16029467ebb926a9a21374917.jpg
# 图片地址: /govweb/c1465t/202003/5492078/images/5b8c9c717b364360809ad5e0da32ac34.jpg
# 图片地址: /govweb/c1465t/202003/5492674/images/1ce20319868b431fa77159a74ff307c3.jpg
# 图片地址: /govweb/c1465t/202003/5492655/images/3e6cd656325246b48102e774d02940cc.jpg
# 图片地址: /govweb/c1465t/202003/5492635/images/47b8e495a821490b847e497750aa470b.jpg
# 图片地址: /govweb/c1465t/202003/5492576/images/a1fde93a80f14d78bc628e3ac191e298.jpg
# 图片地址: /govweb/c1465t/202003/5492555/images/7d3491a7348c46708d25cf0fac2885b8.jpg
# 图片地址: /govweb/c1465t/202003/5492551/images/239c332708ba4502ac045d41598d2175.jpg
# 图片地址: /govweb/c1465t/202003/5491690/images/9d338dfa93c4400ca3d3b1578e2aba89.jpg
# 图片地址: /govweb/c1465t/202003/5490944/images/425ef26539774febab69963122d5eaa4.jpg
# 图片地址: /govweb/c1465t/202001/5472021/images/1dcf69ab6152498f81681f2fa9da5453.jpg
# 图片地址: /govweb/c1465t/202003/5491871/images/c650c9be9bc0451484d501b346bd857c.jpg
# 图片地址: /govweb/c1465t/202003/5491547/images/70f09cc463d248b284eea4a102837210.jpg
# 图片地址: /govweb/c1465t/202003/5490963/images/afeea1153cde4b729f4876dc78f7b08a.jpg

# %%
from requests_html import HTMLSession

session = HTMLSession()

r = session.get("http://www.gov.cn/xinwen/tupian/index.htm")

# 通过xpath找到工作标签
Bing_news = r.html.xpath('//div[@class="title-inner"]/span[2]/a')

for Bing_new in Bing_news:
    print(Bing_new.text)
    print(Bing_new.absolute_links)
# Out:
# 时政
# {'http://www.gov.cn/xinwen/tupian/shizheng.htm'}
# 经济
# {'http://www.gov.cn/xinwen/tupian/jingji.htm'}
# 社会
# {'http://www.gov.cn/xinwen/tupian/shehui.htm'}
# 文化
# {'http://www.gov.cn/xinwen/tupian/wenhua.htm'}
# 生态
# {'http://www.gov.cn/xinwen/tupian/shengtai.htm'}

# %%
import pandas as pd
from requests_html import HTMLSession


payload = {
    "keyword":"PRD",
}

session = HTMLSession()
r = session.get("https://www.liepin.com/zhaopin/?keyword=", params=payload)



df= pd.DataFrame( {
    "edu": r.html.xpath('//div[contains(@class,"job-info")]/p/span[@class="edu"]'),
    "经验": r.html.xpath('//div[contains(@class,"job-info")]/p/span[@class="edu"]/following-sibling::span'),
    "薪水": r.html.xpath('//div[contains(@class,"job-info")]/p/span[@class="text-warning"]'),
    "时间": r.html.xpath('//div[contains(@class,"job-info")]/p/time/@title'),
    "职称": r.html.xpath('//div[contains(@class,"job-info")]/h3/a')
    
} )

df
# Out:
#                                 edu                 经验  \
# 0   <Element 'span' class=('edu',)>  <Element 'span' >
# 1   <Element 'span' class=('edu',)>  <Element 'span' >
# 2   <Element 'span' class=('edu',)>  <Element 'span' >
# 3   <Element 'span' class=('edu',)>  <Element 'span' >
# 4   <Element 'span' class=('edu',)>  <Element 'span' >
# 5   <Element 'span' class=('edu',)>  <Element 'span' >
# 6   <Element 'span' class=('edu',)>  <Element 'span' >
# 7   <Element 'span' class=('edu',)>  <Element 'span' >
# 8   <Element 'span' class=('edu',)>  <Element 'span' >
# 9   <Element 'span' class=('edu',)>  <Element 'span' >
# 10  <Element 'span' class=('edu',)>  <Element 'span' >
# 11  <Element 'span' class=('edu',)>  <Element 'span' >
# 12  <Element 'span' class=('edu',)>  <Element 'span' >
# 13  <Element 'span' class=('edu',)>  <Element 'span' >
# 14  <Element 'span' class=('edu',)>  <Element 'span' >
# 15  <Element 'span' class=('edu',)>  <Element 'span' >
# 16  <Element 'span' class=('edu',)>  <Element 'span' >
# 17  <Element 'span' class=('edu',)>  <Element 'span' >
# 18  <Element 'span' class=('edu',)>  <Element 'span' >
# 19  <Element 'span' class=('edu',)>  <Element 'span' >
# 20  <Element 'span' class=('edu',)>  <Element 'span' >
# 21  <Element 'span' class=('edu',)>  <Element 'span' >
# 22  <Element 'span' class=('edu',)>  <Element 'span' >
# 23  <Element 'span' class=('edu',)>  <Element 'span' >
# 24  <Element 'span' class=('edu',)>  <Element 'span' >
# 25  <Element 'span' class=('edu',)>  <Element 'span' >
# 26  <Element 'span' class=('edu',)>  <Element 'span' >
# 27  <Element 'span' class=('edu',)>  <Element 'span' >
# 28  <Element 'span' class=('edu',)>  <Element 'span' >
# 29  <Element 'span' class=('edu',)>  <Element 'span' >
# 30  <Element 'span' class=('edu',)>  <Element 'span' >
# 31  <Element 'span' class=('edu',)>  <Element 'span' >
# 32  <Element 'span' class=('edu',)>  <Element 'span' >
# 33  <Element 'span' class=('edu',)>  <Element 'span' >
# 34  <Element 'span' class=('edu',)>  <Element 'span' >
# 35  <Element 'span' class=('edu',)>  <Element 'span' >
# 36  <Element 'span' class=('edu',)>  <Element 'span' >
# 37  <Element 'span' class=('edu',)>  <Element 'span' >
# 38  <Element 'span' class=('edu',)>  <Element 'span' >
# 39  <Element 'span' class=('edu',)>  <Element 'span' >
#
#                                           薪水           时间  \
# 0   <Element 'span' class=('text-warning',)>  2020年04月07日
# 1   <Element 'span' class=('text-warning',)>  2020年04月07日
# 2   <Element 'span' class=('text-warning',)>  2020年04月07日
# 3   <Element 'span' class=('text-warning',)>  2020年04月07日
# 4   <Element 'span' class=('text-warning',)>  2020年04月07日
# 5   <Element 'span' class=('text-warning',)>  2020年04月07日
# 6   <Element 'span' class=('text-warning',)>  2020年04月07日
# 7   <Element 'span' class=('text-warning',)>  2020年04月07日
# 8   <Element 'span' class=('text-warning',)>  2020年04月07日
# 9   <Element 'span' class=('text-warning',)>  2020年04月07日
# 10  <Element 'span' class=('text-warning',)>  2020年04月07日
# 11  <Element 'span' class=('text-warning',)>  2020年04月07日
# 12  <Element 'span' class=('text-warning',)>  2020年04月07日
# 13  <Element 'span' class=('text-warning',)>  2020年04月07日
# 14  <Element 'span' class=('text-warning',)>  2020年04月07日
# 15  <Element 'span' class=('text-warning',)>  2020年04月07日
# 16  <Element 'span' class=('text-warning',)>  2020年04月07日
# 17  <Element 'span' class=('text-warning',)>  2020年04月07日
# 18  <Element 'span' class=('text-warning',)>  2020年04月07日
# 19  <Element 'span' class=('text-warning',)>  2020年04月07日
# 20  <Element 'span' class=('text-warning',)>  2020年04月07日
# 21  <Element 'span' class=('text-warning',)>  2020年04月07日
# 22  <Element 'span' class=('text-warning',)>  2020年04月07日
# 23  <Element 'span' class=('text-warning',)>  2020年04月07日
# 24  <Element 'span' class=('text-warning',)>  2020年04月07日
# 25  <Element 'span' class=('text-warning',)>  2020年04月07日
# 26  <Element 'span' class=('text-warning',)>  2020年04月07日
# 27  <Element 'span' class=('text-warning',)>  2020年04月07日
# 28  <Element 'span' class=('text-warning',)>  2020年04月07日
# 29  <Element 'span' class=('text-warning',)>  2020年04月07日
# 30  <Element 'span' class=('text-warning',)>  2020年04月07日
# 31  <Element 'span' class=('text-warning',)>  2020年04月07日
# 32  <Element 'span' class=('text-warning',)>  2020年04月07日
# 33  <Element 'span' class=('text-warning',)>  2020年04月07日
# 34  <Element 'span' class=('text-warning',)>  2020年04月07日
# 35  <Element 'span' class=('text-warning',)>  2020年04月07日
# 36  <Element 'span' class=('text-warning',)>  2020年04月07日
# 37  <Element 'span' class=('text-warning',)>  2020年04月07日
# 38  <Element 'span' class=('text-warning',)>  2020年04月07日
# 39  <Element 'span' class=('text-warning',)>  2020年04月07日
#
#                                                    职称
# 0   <Element 'a' data-promid='imscid=R000000075&ck...
# 1   <Element 'a' data-promid='imscid=R000000075&ck...
# 2   <Element 'a' data-promid='imscid=R000000075&ck...
# 3   <Element 'a' data-promid='imscid=R000000075&ck...
# 4   <Element 'a' data-promid='imscid=R000000075&ck...
# 5   <Element 'a' data-promid='imscid=R000000075&ck...
# 6   <Element 'a' data-promid='imscid=R000000075&ck...
# 7   <Element 'a' data-promid='imscid=R000000075&ck...
# 8   <Element 'a' data-promid='imscid=R000000075&ck...
# 9   <Element 'a' data-promid='imscid=R000000075&ck...
# 10  <Element 'a' data-promid='imscid=R000000075&ck...
# 11  <Element 'a' data-promid='imscid=R000000075&ck...
# 12  <Element 'a' data-promid='imscid=R000000075&ck...
# 13  <Element 'a' data-promid='imscid=R000000075&ck...
# 14  <Element 'a' data-promid='imscid=R000000075&ck...
# 15  <Element 'a' data-promid='imscid=R000000075&ck...
# 16  <Element 'a' data-promid='imscid=R000000075&ck...
# 17  <Element 'a' data-promid='imscid=R000000075&ck...
# 18  <Element 'a' data-promid='imscid=R000000075&ck...
# 19  <Element 'a' data-promid='imscid=R000000075&ck...
# 20  <Element 'a' data-promid='imscid=R000000075&ck...
# 21  <Element 'a' data-promid='imscid=R000000075&ck...
# 22  <Element 'a' data-promid='imscid=R000000075&ck...
# 23  <Element 'a' data-promid='imscid=R000000075&ck...
# 24  <Element 'a' data-promid='imscid=R000000075&ck...
# 25  <Element 'a' data-promid='imscid=R000000075&ck...
# 26  <Element 'a' data-promid='imscid=R000000075&ck...
# 27  <Element 'a' data-promid='imscid=R000000075&ck...
# 28  <Element 'a' data-promid='imscid=R000000075&ck...
# 29  <Element 'a' data-promid='imscid=R000000075&ck...
# 30  <Element 'a' data-promid='imscid=R000000075&ck...
# 31  <Element 'a' data-promid='imscid=R000000075&ck...
# 32  <Element 'a' data-promid='imscid=R000000075&ck...
# 33  <Element 'a' data-promid='imscid=R000000075&ck...
# 34  <Element 'a' data-promid='imscid=R000000075&ck...
# 35  <Element 'a' data-promid='imscid=R000000075&ck...
# 36  <Element 'a' data-promid='imscid=R000000075&ck...
# 37  <Element 'a' data-promid='imscid=R000000075&ck...
# 38  <Element 'a' data-promid='imscid=R000000075&ck...
# 39  <Element 'a' data-promid='imscid=R000000075&ck...

# %%
# C-1   单一页面

import pandas as pd
from requests_html import HTMLSession

url = "https://m.liepin.com/zhaopin/?keyword=PRD"
session = HTMLSession()
r = session.get( url )

# C-5
# 难: '公司URL', '时间', '经验'

# 先取特定元素, 精准打击其子后辈 最常用到的属性
主要元素 = r.html.xpath( \
    '//div[@class="job-card-wrap"]//div[@class="job-card"]')

# 作为xpath字典，键为我要抓的牛肉名称，值为xpath
dict_xpaths={ 
    'text': { # 因为经验标签在li集合里面，而li里面也有time和a标签，所以要取经验时可以用[]集合的方式，如[a]/[time]
        '经验':      './/ul/li[a]/text()' # li[]中的[]表示1.应用筛选模式（即谓词，包括"过滤表达式"和"轴（向前/向后）"）。2.下标运算符；用于在集合中编制索引。
    },
    'text_content': {
        '职称':    './/ul/li/a[contains(@class,"job-name")]/span[@class="name-text"]', 
        '薪水':    './/ul/li/a[contains(@class,"job-name")]/following-sibling::span',  # :表示命名空间分隔符；将命名空间前缀与元素名或属性名分隔。
        '公司地点':'.//ul/li/time/following-sibling::a',  #  following-sibling::获取弟节点-下一个同级节点
        '公司名称': './/ul/li/a[contains(@class,"company-name")]', 
        '时间':    './/ul/li/time', 
       
    },
    'href': {
        '链结':    './/ul/li/a[contains(@class,"job-name")]', 
        '公司URL': './/ul/li/a[contains(@class,"company-name")]',  # contains用法：需要调用多个同一属性的消。举例：//input[contains(@name,'na')] 查找name属性中包含na关键字的页面元素
    }
}

def get_e_text_content(_xpath_):
    # 高级列表推导
    暂存结果 = [e.xpath(_xpath_)[0].lxml.text_content() for e in 主要元素]
    return(暂存结果)

def get_e_text(_xpath_):
    # 高级列表推导
    暂存结果 = ["".join([x.strip() for x in e.xpath(_xpath_)]) for e in 主要元素]
    return(暂存结果)

def get_e_href(_xpath_):
    # 高级列表推导
    暂存结果 = [list(e.xpath(_xpath_, first=True).absolute_links)[0] \
               if len(e.xpath(_xpath_, first=True).absolute_links) >= 1  \
               else "" for e in 主要元素]
    return(暂存结果)

# 只对主要元素下进行.xpath取值
数据字典 = dict()

# dict.update（dict2）  把字典dict2里更新到dict里
数据字典 = {k:get_e_text_content(v) for k,v in dict_xpaths['text_content'].items()}
数据字典.update({k:get_e_text(v) for k,v in dict_xpaths['text'].items()})
数据字典.update({k:get_e_href(v) for k,v in dict_xpaths['href'].items()})

print ([len(v) for k,v in 数据字典.items()])  # 檢查

数据 = pd.DataFrame(数据字典)
数据.to_excel("20春_Web数据挖掘_week02_liepin.xlsx", sheet_name="搜查结果")
数据
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3]
#         职称          薪水 公司地点               公司名称    时间          经验  \
# 0  数据产品经理   10-15k·17薪   惠州  TCL实业控股(广东)股份有限公司    前天  3年以上 大专及以上
# 1  高级产品经理           面议   惠州       惠州酷友网络科技有限公司  一个月前  5年以上 本科及以上
# 2  数据产品经理   15-25k·12薪   惠州       惠州酷友网络科技有限公司  一个月前  3年以上 本科及以上
#
#                                           链结  \
# 0  https://m.liepin.com/job/1926925221.shtml
# 1  https://m.liepin.com/job/1923794249.shtml
# 2  https://m.liepin.com/job/1923475657.shtml
#
#                                    公司URL
# 0  https://m.liepin.com/company/7876341/
# 1  https://m.liepin.com/company/8109237/
# 2  https://m.liepin.com/company/8109237/

# %%
# A-1   单一页面
url = "https://www.liepin.com/zhaopin/?keyword="
session = HTMLSession()
r = session.get( url )

# 先取特定元素, 精准打击其子后辈
主要元素 = r.html.xpath( \
    '//ul[@class="sojob-list"]/li')

# 预期是一个元素的列表？
#print (主要元素[0].xpath('//div[contains(@class,"sojob-item-main")]'))
#print (主要元素[0].xpath('//div[contains(@class,"job-info")]/h3/a'))
#print (主要元素[3].xpath('//div[contains(@class,"job-info")]/p/a'))
#print (主要元素[3].xpath('//div[contains(@class,"job-info")]/p/span[@class="text-warning"]'))
#print (主要元素[3].xpath('//div[contains(@class,"job-info")]/p/span[@class="edu"]/following-sibling::span'))
#print (主要元素[3].xpath('//div[contains(@class,"job-info")]/p/time/@title'))
#print (主要元素[0].xpath('//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a'))

# 作为xpath字典，键为我要抓的牛肉名称，值为xpath
dict_xpaths={ 
    'text': {
        'edu':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]',
        '经验':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]/following-sibling::span',
        '薪水':    '//div[contains(@class,"job-info")]/p/span[@class="text-warning"]', 
        '时间':    '//div[contains(@class,"job-info")]/p/time/@title', 
        '职称':    '//div[contains(@class,"job-info")]/h3/a', 
        '公司地点': '//div[contains(@class,"job-info")]/p/a',
        '公司名称': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
    },
    'text_content': {
    },
    'href': {
        '链结':    '//div[contains(@class,"job-info")]/h3/a', 
        '公司URL': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
    }
}

def get_e_text_content(_xpath_):
    # 高级列表推导
    暂存结果 = [e.xpath(_xpath_)[0].lxml.text_content() for e in 主要元素]
    return(暂存结果)

def get_e_text(_xpath_):
    # 高级列表推导
    暂存结果 = ["".join([x.strip() if type(x) is str else x.text.strip() for x in e.xpath(_xpath_)]) for e in 主要元素]
    return(暂存结果)

def get_e_href(_xpath_):
    # 高级列表推导
    暂存结果 = [list(e.xpath(_xpath_, first=True).absolute_links)[0] \
               if len(e.xpath(_xpath_, first=True).absolute_links) >= 1  \
               else "" for e in 主要元素]
    return(暂存结果)

# 只对主要元素下进行.xpath取值
数据字典 = dict()

数据字典 = {k:get_e_text_content(v) for k,v in dict_xpaths['text_content'].items()}
